# %%
from tkinter import *
from tkinter import filedialog,messagebox
import random
import time
import requests

#Functions

def reset():
    textReceipt.delete(1.0,END)
    e_Frappe.set('0')
    e_Espresso.set('0')
    e_Smoothie.set('0')
    e_Mojito.set('0')
    e_Latte.set('0')
    e_Juice.set('0')
    e_Tea.set('0')
    e_Mocha.set('0')
    e_Cold_Coffee.set('0')

    e_Sandwich.set('0')
    e_Burger.set('0')
    e_Pasta.set('0')
    e_Nuggets.set('0')
    e_Burrito.set('0')
    e_Noodles.set('0')
    e_masalatea.set('0')
    e_badammilk.set('0')
    e_colSnacks.set('0')

    e_Cheesecake.set('0')
    e_Cake.set('0')
    e_Brownie.set('0')
    e_Cookies.set('0')
    e_Puddings.set('0')
    e_Donut.set('0')
    e_Muffin.set('0')
    e_Sundae.set('0')
    e_blackforest.set('0')

    textEspresso.config(state=DISABLED)
    textFrappe.config(state=DISABLED)
    textSmoothie.config(state=DISABLED)
    textMojito.config(state=DISABLED)
    textLatte.config(state=DISABLED)
    textMocha.config(state=DISABLED)
    textColdCoffee.config(state=DISABLED)
    textTea.config(state=DISABLED)
    textJuice.config(state=DISABLED)

    textSandwich.config(state=DISABLED)
    textBurger.config(state=DISABLED)
    textNoodles.config(state=DISABLED)
    textNuggets.config(state=DISABLED)
    textBurrito.config(state=DISABLED)
    textbadammilk.config(state=DISABLED)
    textmasalatea.config(state=DISABLED)
    textPasta.config(state=DISABLED)
    textcoldSnacks.config(state=DISABLED)

    textCake.config(state=DISABLED)
    textBrownie.config(state=DISABLED)
    textCheesecake.config(state=DISABLED)
    textCookies.config(state=DISABLED)
    textPuddings.config(state=DISABLED)
    textDonut.config(state=DISABLED)
    textMuffin.config(state=DISABLED)
    textSundae.config(state=DISABLED)
    textblackforest.config(state=DISABLED)

    var1.set(0)
    var2.set(0)
    var3.set(0)
    var4.set(0)
    var5.set(0)
    var6.set(0)
    var7.set(0)
    var8.set(0)
    var9.set(0)
    var10.set(0)
    var11.set(0)
    var12.set(0)
    var13.set(0)
    var14.set(0)
    var15.set(0)
    var16.set(0)
    var17.set(0)
    var18.set(0)
    var19.set(0)
    var20.set(0)
    var21.set(0)
    var22.set(0)
    var23.set(0)
    var24.set(0)
    var25.set(0)
    var26.set(0)
    var27.set(0)

    costofSnacksvar.set('')
    costofDrinksvar.set('')
    costofDessertsvar.set('')
    subtotalvar.set('')
    servicetaxvar.set('')
    totalcostvar.set('')


def save():
    if textReceipt.get(1.0,END)=='\n':
        pass
    else:
        url=filedialog.asksaveasfile(mode='w',defaultextension='.txt')
        if url==None:
            pass
        else:

            bill_data=textReceipt.get(1.0,END)
            url.write(bill_data)
            url.close()
            messagebox.showinfo('Information','Your Bill Is Succesfully Saved')

def receipt():
    global billnumber,date
    if costofDrinksvar.get() != '' or costofDessertsvar.get() != '' or costofSnacksvar.get() != '':
        textReceipt.delete(1.0,END)
        x=random.randint(100,10000)
        billnumber='BILL'+str(x)
        date=time.strftime('%d/%m/%Y')
        textReceipt.insert(END,'Receipt Ref:\t\t'+billnumber+'\t\t'+date+'\n')
        textReceipt.insert(END,'***************************************************************\n')
        textReceipt.insert(END,'Items:\t\t Cost Of Items(Rs)\n')
        textReceipt.insert(END,'***************************************************************\n')
        if e_Espresso.get()!='0':
            textReceipt.insert(END,f'Espresso\t\t\t{int(e_Espresso.get())*10}\n\n')

        if e_Frappe.get()!='0':
            textReceipt.insert(END,f'Frappe\t\t\t{int(e_Frappe.get())*60}\n\n')

        if e_Mojito.get()!='0':
            textReceipt.insert(END,f'Mojito\t\t\t{int(e_Mojito.get())*100}\n\n')

        if e_Juice.get() != '0':
            textReceipt.insert(END, f'Juice:\t\t\t{int(e_Juice.get()) * 30}\n\n')

        if e_Smoothie.get() != '0':
            textReceipt.insert(END, f'Smoothie:\t\t\t{int(e_Smoothie.get()) * 50}\n\n')

        if e_Mocha.get() != '0':
            textReceipt.insert(END, f'Mocha:\t\t\t{int(e_Mocha.get()) * 100}\n\n')

        if e_Latte.get() != '0':
            textReceipt.insert(END, f'Latte:\t\t\t{int(e_Latte.get()) * 40}\n\n')

        if e_ColdCoffee.get() != '0':
            textReceipt.insert(END, f'ColdCoffee:\t\t\t{int(e_Cold_Coffee.get()) * 120}\n\n')

        if e_Tea.get() != '0':
            textReceipt.insert(END, f'Tea:\t\t\t{int(e_Tea.get()) * 120}\n\n')

        if e_Sandwich.get() != '0':
            textReceipt.insert(END, f'Sandwich:\t\t\t{int(e_Sandwich.get()) * 50}\n\n')

        if e_Burger.get() != '0':
            textReceipt.insert(END, f'Burger:\t\t\t{int(e_Burger.get()) * 40}\n\n')

        if e_Pasta.get() != '0':
            textReceipt.insert(END, f'Pasta:\t\t\t{int(e_Pasta.get()) * 80}\n\n')

        if e_Burrito.get() != '0':
            textReceipt.insert(END, f'Burrito:\t\t\t{int(e_Burrito.get()) * 30}\n\n')

        if e_Noodles.get() != '0':
            textReceipt.insert(END, f'Noodles:\t\t\t{int(e_Noodles.get()) * 40}\n\n')

        if e_Nuggets.get() != '0':
            textReceipt.insert(END, f'Nuggets:\t\t\t{int(e_Nuggets.get()) * 60}\n\n')

        if e_masalatea.get() != '0':
            textReceipt.insert(END, f'Masala Chai:\t\t\t{int(e_masalatea.get()) * 20}\n\n')

        if e_badammilk.get() != '0':
            textReceipt.insert(END, f'French fries:\t\t\t{int(e_badammilk.get()) * 50}\n\n')

        if e_colSnacks.get() != '0':
            textReceipt.insert(END, f'Garlic Breads:\t\t\t{int(e_colSnacks.get()) * 80}\n\n')

        if e_Cake.get() != '0':
            textReceipt.insert(END, f'Cake:\t\t\t{int(e_Cake.get()) * 400}\n\n')

        if e_Brownie.get() != '0':
            textReceipt.insert(END, f'Brownie:\t\t\t{int(e_Brownie.get()) * 300}\n\n')

        if e_Cheesecake.get() != '0':
            textReceipt.insert(END, f'Cheesecake:\t\t\t{int(e_Cheesecake.get()) * 500}\n\n')

        if e_Puddings.get() != '0':
            textReceipt.insert(END, f'Puddings:\t\t\t{int(e_Puddings.get()) * 450}\n\n')

        if e_Donut.get() != '0':
            textReceipt.insert(END, f'Donut:\t\t\t{int(e_Donut.get()) * 800}\n\n')

        if e_Muffin.get() != '0':
            textReceipt.insert(END, f'Muffin:\t\t\t{int(e_Muffin.get()) * 620}\n\n')

        if e_Sundae.get() != '0':
            textReceipt.insert(END, f'Sundae:\t\t\t{int(e_Sundae.get()) * 700}\n\n')

        if e_blackforest.get() != '0':
            textReceipt.insert(END, f'Ice Cream:\t\t\t{int(e_blackforest.get()) * 550}\n\n')

        if e_Cookies.get() != '0':
            textReceipt.insert(END, f'Cookies:\t\t\t{int(e_Cookies.get()) * 550}\n\n')

        textReceipt.insert(END,'***************************************************************\n')
        if costofDrinksvar.get()!='0 Rs':
            textReceipt.insert(END,f'Cost Of Drinks\t\t\t{priceofDrinks}Rs\n\n')
        if costofSnacksvar.get() != '0 Rs':
            textReceipt.insert(END,f'Cost Of Snacks\t\t\t{priceofSnacks}Rs\n\n')
        if costofDessertsvar.get() != '0 Rs':
            textReceipt.insert(END,f'Cost Of Desserts\t\t\t{priceofDesserts}Rs\n\n')

        textReceipt.insert(END, f'Sub Total\t\t\t{subtotalofItems}Rs\n\n')
        textReceipt.insert(END, f'Service Tax\t\t\t{50}Rs\n\n')
        textReceipt.insert(END, f'Total Cost\t\t\t{subtotalofItems+50}Rs\n\n')
        textReceipt.insert(END,'***************************************************************\n')

    else:
        messagebox.showerror('Error','No Item Is selected')



def totalcost():
    global priceofDrinks,priceofSnacks,priceofDesserts,subtotalofItems
    if var1.get() != 0 or var2.get() != 0 or var3.get() != 0 or var4.get() != 0 or var5.get() != 0 or \
        var6.get() != 0 or var7.get() != 0 or var8.get() != 0 or var9.get() != 0 or var10.get() != 0 or\
        var11.get() != 0 or var12.get() != 0 or var13.get() != 0 or var14.get() != 0 or var15.get() != 0 or \
        var16.get() != 0 or var17.get() != 0 or var18.get() != 0 or var19.get() != 0 or var20.get() != 0 or \
        var21.get() != 0 or var22.get() != 0 or var23.get() != 0 or var24.get() != 0 or var25.get() != 0 or\
        var26.get() != 0 or var27.get() != 0:

        item1=int(e_Espresso.get())
        item2=int(e_Frappe.get())
        item3=int(e_Mojito.get())
        item4 = int(e_Smoothie.get())
        item5 = int(e_Latte.get())
        item6 = int(e_Juice.get())
        item7 = int(e_Tea.get())
        item8 = int(e_Mocha.get())
        item9 = int(e_ColdCoffee.get())

        item10 = int(e_Sandwich.get())
        item11 = int(e_Burger.get())
        item12 = int(e_Pasta.get())
        item13 = int(e_Burrito.get())
        item14 = int(e_Noodles.get())
        item15 = int(e_Nuggets.get())
        item16 = int(e_masalatea.get())
        item17 = int(e_badammilk.get())
        item18 = int(e_colSnacks.get())

        item19 = int(e_Cake.get())
        item20 = int(e_Brownie.get())
        item21 = int(e_Cheesecake.get())
        item22 = int(e_Cookies.get())
        item23 = int(e_Puddings.get())
        item24 = int(e_Donut.get())
        item25 = int(e_Muffin.get())
        item26 = int(e_Sundae.get())
        item27 = int(e_blackforest.get())

        priceofDrinks=(item1*89)+(item2*109)+(item3*129)+(item4*119)+ (item5*99) + (item6 * 79) + (item7 * 110) \
                    + (item8 * 130) + (item9 * 100)

        priceofSnacks=(item10*108)+(item11*127)+ (item12 * 114) + (item13 * 159) + (item14 * 142) + (item15 * 105) \
                      + (item16 * 198) + (item17 * 104) + (item18 * 103)

        priceofDesserts=(item19*399)+(item20*148)+ (item21 * 300) + (item22 * 69) + (item23 * 150) + (item24 * 80) \
                     + (item25 * 102) + (item26 * 110) + (item27 * 107)

        costofDrinksvar.set(str(priceofDrinks)+ ' Rs')
        costofSnacksvar.set(str(priceofSnacks)+ ' Rs')
        costofDessertsvar.set(str(priceofDesserts)+ ' Rs')

        subtotalofItems=priceofDrinks+priceofSnacks+priceofDesserts
        subtotalvar.set(str(subtotalofItems)+' Rs')

        servicetaxvar.set('50 Rs')

        tottalcost=subtotalofItems+50
        totalcostvar.set(str(tottalcost)+' Rs')

    else:
        messagebox.showerror('Error','No Item Is selected')



def Espresso():
    if var1.get()==1:
        textEspresso.config(state=NORMAL)
        textEspresso.delete(0,END)
        textEspresso.focus()
    else:
        textEspresso.config(state=DISABLED)
        e_Espresso.set('0')

def Frappe():
    if var2.get()==1:
        textFrappe.config(state=NORMAL)
        textFrappe.delete(0,END)
        textFrappe.focus()

    else:
        textFrappe.config(state=DISABLED)
        e_Frappe.set('0')

def Mojito():
    if var3.get()==1:
        textMojito.config(state=NORMAL)
        textMojito.delete(0,END)
        textMojito.focus()

    else:
        textMojito.config(state=DISABLED)
        e_Mojito.set('0')

def Smoothie():
    if var4.get() == 1:
        textSmoothie.config(state=NORMAL)
        textSmoothie.focus()
        textSmoothie.delete(0, END)
    elif var4.get() == 0:
        textSmoothie.config(state=DISABLED)
        e_Smoothie.set('0')


def Latte():
    if var5.get() == 1:
        textLatte.config(state=NORMAL)
        textLatte.focus()
        textLatte.delete(0, END)
    elif var5.get() == 0:
        textLatte.config(state=DISABLED)
        e_Latte.set('0')


def Juice():
    if var6.get() == 1:
        textJuice.config(state=NORMAL)
        textJuice.focus()
        textJuice.delete(0, END)
    elif var6.get() == 0:
        textJuice.config(state=DISABLED)
        e_Juice.set('0')


def Tea():
    if var7.get() == 1:
        textTea.config(state=NORMAL)
        textTea.focus()
        textTea.delete(0, END)
    elif var7.get() == 0:
        textTea.config(state=DISABLED)
        e_Tea.set('0')


def Mocha():
    if var8.get() == 1:
        textMocha.config(state=NORMAL)
        textMocha.focus()
        textMocha.delete(0, END)
    elif var8.get() == 0:
        textMocha.config(state=DISABLED)
        e_Mocha.set('0')


def ColdCoffee():
    if var9.get() == 1:
        textColdCoffee.config(state=NORMAL)
        textColdCoffee.focus()
        textColdCoffee.delete(0, END)
    elif var9.get() == 0:
        textColdCoffee.config(state=DISABLED)
        e_ColdCoffee.set('0')


def Sandwich():
    if var10.get() == 1:
        textSandwich.config(state=NORMAL)
        textSandwich.focus()
        textSandwich.delete(0, END)
    elif var10.get() == 0:
        textSandwich.config(state=DISABLED)
        e_Sandwich.set('0')


def Burger():
    if var11.get() == 1:
        textBurger.config(state=NORMAL)
        textBurger.focus()
        textBurger.delete(0, END)
    elif var11.get() == 0:
        textBurger.config(state=DISABLED)
        e_Burger.set('0')


def Pasta():
    if var12.get() == 1:
        textPasta.config(state=NORMAL)
        textPasta.focus()
        textPasta.delete(0, END)
    elif var12.get() == 0:
        textPasta.config(state=DISABLED)
        e_Pasta.set('0')


def Burrito():
    if var13.get() == 1:
        textBurrito.config(state=NORMAL)
        textBurrito.focus()
        textBurrito.delete(0, END)
    elif var13.get() == 0:
        textBurrito.config(state=DISABLED)
        e_Burrito.set('0')


def Noodles():
    if var14.get() == 1:
        textNoodles.config(state=NORMAL)
        textNoodles.focus()
        textNoodles.delete(0, END)
    elif var14.get() == 0:
        textNoodles.config(state=DISABLED)
        e_Noodles.set('0')


def Nuggets():
    if var15.get() == 1:
        textNuggets.config(state=NORMAL)
        textNuggets.focus()
        textNuggets.delete(0, END)
    elif var15.get() == 0:
        textNuggets.config(state=DISABLED)
        e_Nuggets.set('0')


def masalatea():
    if var16.get() == 1:
        textmasalatea.config(state=NORMAL)
        textmasalatea.focus()
        textmasalatea.delete(0, END)
    elif var16.get() == 0:
        textmasalatea.config(state=DISABLED)
        e_masalatea.set('0')


def badammilk():
    if var17.get() == 1:
        textbadammilk.config(state=NORMAL)
        textbadammilk.focus()
        textbadammilk.delete(0, END)
    elif var17.get() == 0:
        textbadammilk.config(state=DISABLED)
        e_badammilk.set('0')


def coldSnacks():
    if var18.get() == 1:
        textcoldSnacks.config(state=NORMAL)
        textcoldSnacks.focus()
        textcoldSnacks.delete(0, END)
    elif var18.get() == 0:
        textcoldSnacks.config(state=DISABLED)
        e_colSnacks.set('0')


def Cake():
    if var19.get() == 1:
        textCake.config(state=NORMAL)
        textCake.focus()
        textCake.delete(0, END)
    elif var19.get() == 0:
        textCake.config(state=DISABLED)
        e_Cake.set('0')


def Brownie():
    if var20.get() == 1:
        textBrownie.config(state=NORMAL)
        textBrownie.focus()
        textBrownie.delete(0, END)
    elif var20.get() == 0:
        textBrownie.config(state=DISABLED)
        e_Brownie.set('0')


def Cheesecake():
    if var21.get() == 1:
        textCheesecake.config(state=NORMAL)
        textCheesecake.focus()
        textCheesecake.delete(0, END)
    elif var21.get() == 0:
        textCheesecake.config(state=DISABLED)
        e_Cheesecake.set('0')


def Cookies():
    if var22.get() == 1:
        textCookies.config(state=NORMAL)
        textCookies.focus()
        textCookies.delete(0, END)
    elif var22.get() == 0:
        textCookies.config(state=DISABLED)
        e_Cookies.set('0')


def Puddings():
    if var23.get() == 1:
        textPuddings.config(state=NORMAL)
        textPuddings.focus()
        textPuddings.delete(0, END)
    elif var23.get() == 0:
        textPuddings.config(state=DISABLED)
        e_Puddings.set('0')


def Donut():
    if var24.get() == 1:
        textDonut.config(state=NORMAL)
        textDonut.focus()
        textDonut.delete(0, END)
    elif var24.get() == 0:
        textbDonut.config(state=DISABLED)
        e_Donut.set('0')


def Muffin():
    if var25.get() == 1:
        textMuffin.config(state=NORMAL)
        textMuffin.focus()
        textMuffin.delete(0, END)
    elif var25.get() == 0:
        textMuffin.config(state=DISABLED)
        e_Muffin.set('0')


def Sundae():
    if var26.get() == 1:
        textSundae.config(state=NORMAL)
        textSundae.focus()
        textSundae.delete(0, END)
    elif var26.get() == 0:
        textSundae.config(state=DISABLED)
        e_Sundae.set('0')


def blackforest():
    if var27.get() == 1:
        textblackforest.config(state=NORMAL)
        textblackforest.focus()
        textblackforest.delete(0, END)
    elif var27.get() == 0:
        textblackforest.config(state=DISABLED)
        e_blackforest.set('0')



root=Tk()

root.geometry('1270x690+0+0')

root.resizable(0,0)

root.title('Cafe Management System')

root.config(bg='firebrick4')

topFrame=Frame(root,bd=10,relief=RIDGE,bg='firebrick4')
topFrame.pack(side=TOP)

labelTitle=Label(topFrame,text='Cafe Management System',font=('arial',30,'bold'),fg='BLACK',bd=9,
                 bg='GREEN',width=51)
labelTitle.grid(row=0,column=0)

#frames

menuFrame=Frame(root,bd=10,relief=RIDGE,bg='firebrick4')
menuFrame.pack(side=LEFT)

costFrame=Frame(menuFrame,bd=4,relief=RIDGE,bg='firebrick4',pady=10)
costFrame.pack(side=BOTTOM)

DrinksFrame=LabelFrame(menuFrame,text='Drinks',font=('arial',19,'bold'),bd=10,relief=RIDGE,fg='Purple4',)
DrinksFrame.pack(side=LEFT)

SnacksFrame=LabelFrame(menuFrame,text='Snacks',font=('arial',19,'bold'),bd=10,relief=RIDGE,fg='Purple4')
SnacksFrame.pack(side=LEFT)

DessertsFrame=LabelFrame(menuFrame,text='Desserts',font=('arial',19,'bold'),bd=10,relief=RIDGE,fg='Purple4')
DessertsFrame.pack(side=LEFT)

rightFrame=Frame(root,bd=15,relief=RIDGE,bg='Purple4')
rightFrame.pack(side=RIGHT)

calculatorFrame=Frame(rightFrame,bd=1,relief=RIDGE,bg='Purple4')
calculatorFrame.pack()

recieptFrame=Frame(rightFrame,bd=4,relief=RIDGE,bg='Purple4')
recieptFrame.pack()

buttonFrame=Frame(rightFrame,bd=3,relief=RIDGE,bg='Purple4')
buttonFrame.pack()

#Variables

var1=IntVar()
var2=IntVar()
var3=IntVar()
var4=IntVar()
var5 = IntVar()
var6 = IntVar()
var7 = IntVar()
var8 = IntVar()
var9 = IntVar()
var10 = IntVar()
var11 = IntVar()
var12 = IntVar()
var13 = IntVar()
var14 = IntVar()
var15 = IntVar()
var16 = IntVar()
var17 = IntVar()
var18 = IntVar()
var19 = IntVar()
var20 = IntVar()
var21 = IntVar()
var22 = IntVar()
var23 = IntVar()
var24 = IntVar()
var25 = IntVar()
var26 = IntVar()
var27 = IntVar()

e_Espresso=StringVar()
e_Frappe=StringVar()
e_Smoothie = StringVar()
e_Juice = StringVar()
e_Mojito = StringVar()
e_Tea = StringVar()
e_Latte = StringVar()
e_ColdCoffee = StringVar()
e_Mocha = StringVar()

e_Sandwich=StringVar()
e_Burger = StringVar()
e_Pasta = StringVar()
e_Burrito = StringVar()
e_Nuggets = StringVar()
e_Noodles = StringVar()
e_masalatea = StringVar()
e_badammilk = StringVar()
e_colSnacks = StringVar()

e_Cake=StringVar()
e_Cheesecake = StringVar()
e_Cookies = StringVar()
e_Brownie = StringVar()
e_blackforest = StringVar()
e_Puddings = StringVar()
e_Donut = StringVar()
e_Muffin = StringVar()
e_Sundae = StringVar()

costofDrinksvar=StringVar()
costofSnacksvar=StringVar()
costofDessertsvar=StringVar()
subtotalvar=StringVar()
servicetaxvar=StringVar()
totalcostvar=StringVar()

e_Espresso.set('0')
e_Frappe.set('0')
e_Smoothie.set('0')
e_Mojito.set('0')
e_Latte.set('0')
e_Juice.set('0')
e_Tea.set('0')
e_ColdCoffee.set('0')
e_Mocha.set('0')

e_Sandwich.set('0')
e_Burger.set('0')
e_Pasta.set('0')
e_Nuggets.set('0')
e_Burrito.set('0')
e_Noodles.set('0')
e_masalatea.set('0')
e_badammilk.set('0')
e_colSnacks.set('0')

e_Cheesecake.set('0')
e_Puddings.set('0')
e_Muffin.set('0')
e_Brownie.set('0')
e_Sundae.set('0')
e_Cake.set('0')
e_blackforest.set('0')
e_Donut.set('0')
e_Cookies.set('0')

##Drinks

Espresso=Checkbutton(DrinksFrame,text='Espresso',font=('arial',18,'bold'),onvalue=1,offvalue=0,variable=var1
                 ,command=Espresso)
Espresso.grid(row=0,column=0,sticky=W)

Frappe=Checkbutton(DrinksFrame,text='Frappe',font=('arial',18,'bold'),onvalue=1,offvalue=0,variable=var2
                 ,command=Frappe)
Frappe.grid(row=1,column=0,sticky=W)

Mojito=Checkbutton(DrinksFrame,text='Mojito',font=('arial',18,'bold'),onvalue=1,offvalue=0,variable=var3
                 ,command=Mojito)
Mojito.grid(row=2,column=0,sticky=W)

Smoothie=Checkbutton(DrinksFrame,text='Smoothie',font=('arial',18,'bold'),onvalue=1,offvalue=0,variable=var4
                  ,command=Smoothie)
Smoothie.grid(row=3,column=0,sticky=W)

Latte=Checkbutton(DrinksFrame,text='Latte',font=('arial',18,'bold'),onvalue=1,offvalue=0,variable=var5
                  ,command=Latte)
Latte.grid(row=4,column=0,sticky=W)

Juice=Checkbutton(DrinksFrame,text='Juice',font=('arial',18,'bold'),onvalue=1,offvalue=0,variable=var6
                   ,command=Juice)
Juice.grid(row=5,column=0,sticky=W)

Tea=Checkbutton(DrinksFrame,text='Tea',font=('arial',18,'bold'),onvalue=1,offvalue=0,variable=var7,
                   command=Tea)
Tea.grid(row=6,column=0,sticky=W)

Mocha=Checkbutton(DrinksFrame,text='Mocha',font=('arial',18,'bold'),onvalue=1,offvalue=0,variable=var8
                   ,command=Mocha)
Mocha.grid(row=7,column=0,sticky=W)

ColdCoffee=Checkbutton(DrinksFrame,text='ColdCoffee',font=('arial',18,'bold'),onvalue=1,offvalue=0,variable=var9
                    ,command=ColdCoffee)
ColdCoffee.grid(row=8,column=0,sticky=W)

#Entry Fields for Drinks Items

textEspresso=Entry(DrinksFrame,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=e_Espresso)
textEspresso.grid(row=0,column=1)

textFrappe=Entry(DrinksFrame,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=e_Frappe)
textFrappe.grid(row=1,column=1)

textMojito=Entry(DrinksFrame,font=('arial',18,'bold'),bd=7,width=6,state=DISABLED,textvariable=e_Mojito)
textMojito.grid(row=2,column=1)

textSmoothie = Entry(DrinksFrame, font=('arial', 18, 'bold'), bd=7, width=6, state=DISABLED, textvariable=e_Smoothie)
textSmoothie.grid(row=3, column=1)

textLatte = Entry(DrinksFrame, font=('arial', 18, 'bold'), bd=7, width=6, state=DISABLED, textvariable=e_Latte)
textLatte.grid(row=4, column=1)

textJuice = Entry(DrinksFrame, font=('arial', 18, 'bold'), bd=7, width=6, state=DISABLED, textvariable=e_Juice)
textJuice.grid(row=5, column=1)

textTea = Entry(DrinksFrame, font=('arial', 18, 'bold'), bd=7, width=6, state=DISABLED, textvariable=e_Tea)
textTea.grid(row=6, column=1)

textMocha = Entry(DrinksFrame, font=('arial', 18, 'bold'), bd=7, width=6, state=DISABLED, textvariable=e_Mocha)
textMocha.grid(row=7, column=1)

textColdCoffee = Entry(DrinksFrame, font=('arial', 18, 'bold'), bd=7, width=6, state=DISABLED, textvariable=e_ColdCoffee)
textColdCoffee.grid(row=8, column=1)

#Snacks

Sandwich=Checkbutton(SnacksFrame,text='Sandwich',font=('arial',18,'bold'),onvalue=1,offvalue=0,variable=var10
                  ,command=Sandwich)
Sandwich.grid(row=0,column=0,sticky=W)

Burger=Checkbutton(SnacksFrame,text='Burger',font=('arial',18,'bold'),onvalue=1,offvalue=0,variable=var11
                   ,command=Burger)
Burger.grid(row=1,column=0,sticky=W)

Pasta=Checkbutton(SnacksFrame,text='Pasta',font=('arial',18,'bold'),onvalue=1,offvalue=0,variable=var12
                   ,command=Pasta)
Pasta.grid(row=2,column=0,sticky=W)

Burrito=Checkbutton(SnacksFrame,text='Burrito',font=('arial',18,'bold'),onvalue=1,offvalue=0,variable=var13
                     ,command=Burrito)
Burrito.grid(row=3,column=0,sticky=W)

Noodles=Checkbutton(SnacksFrame,text='Noodles',font=('arial',18,'bold'),onvalue=1,offvalue=0,variable=var14
                     ,command=Noodles)
Noodles.grid(row=4,column=0,sticky=W)

Nuggets=Checkbutton(SnacksFrame,text='Nuggets',font=('arial',18,'bold'),onvalue=1,offvalue=0,variable=var15
                     ,command=Nuggets)
Nuggets.grid(row=5,column=0,sticky=W)

masalatea=Checkbutton(SnacksFrame,text='Pizza',font=('arial',18,'bold'),onvalue=1,offvalue=0,variable=var16
                      ,command=masalatea)
masalatea.grid(row=6,column=0,sticky=W)

badammilk=Checkbutton(SnacksFrame,text='French fries',font=('arial',18,'bold'),onvalue=1,offvalue=0,variable=var17
                      ,command=badammilk)
badammilk.grid(row=7,column=0,sticky=W)

coldSnacks=Checkbutton(SnacksFrame,text='Garlic Breads',font=('arial',18,'bold'),onvalue=1,offvalue=0,variable=var18
                       ,command=coldSnacks)
coldSnacks.grid(row=8,column=0,sticky=W)

#entry fields for drink items

textSandwich = Entry(SnacksFrame, font=('arial', 18, 'bold'), bd=7, width=6, state=DISABLED, textvariable=e_Sandwich)
textSandwich.grid(row=0, column=1)

textBurger = Entry(SnacksFrame, font=('arial', 18, 'bold'), bd=7, width=6, state=DISABLED, textvariable=e_Burger)
textBurger.grid(row=1, column=1)

textPasta = Entry(SnacksFrame, font=('arial', 18, 'bold'), bd=7, width=6, state=DISABLED, textvariable=e_Pasta)
textPasta.grid(row=2, column=1)

textBurrito = Entry(SnacksFrame, font=('arial', 18, 'bold'), bd=7, width=6, state=DISABLED, textvariable=e_Burrito)
textBurrito.grid(row=3, column=1)

textNoodles = Entry(SnacksFrame, font=('arial', 18, 'bold'), bd=7, width=6, state=DISABLED, textvariable=e_Noodles)
textNoodles.grid(row=4, column=1)

textNuggets = Entry(SnacksFrame, font=('arial', 18, 'bold'), bd=7, width=6, state=DISABLED, textvariable=e_Nuggets)
textNuggets.grid(row=5, column=1)

textmasalatea = Entry(SnacksFrame, font=('arial', 18, 'bold'), bd=7, width=6, state=DISABLED,textvariable=e_masalatea)
textmasalatea.grid(row=6, column=1)

textbadammilk = Entry(SnacksFrame, font=('arial', 18, 'bold'), bd=7, width=6, state=DISABLED, textvariable=e_badammilk)
textbadammilk.grid(row=7, column=1)

textcoldSnacks = Entry(SnacksFrame, font=('arial', 18, 'bold'), bd=7, width=6, state=DISABLED, textvariable=e_colSnacks)
textcoldSnacks.grid(row=8, column=1)

#Desserts

Cakecake=Checkbutton(DessertsFrame,text='Cake',font=('arial',18,'bold'),onvalue=1,offvalue=0,variable=var19
                     ,command=Cake)
Cakecake.grid(row=0,column=0,sticky=W)

Browniecake=Checkbutton(DessertsFrame,text='Brownie',font=('arial',18,'bold'),onvalue=1,offvalue=0,variable=var20
                      ,command=Brownie)
Browniecake.grid(row=1,column=0,sticky=W)

Cheesecakecake=Checkbutton(DessertsFrame,text='Cheesecake',font=('arial',18,'bold'),onvalue=1,offvalue=0,variable=var21
                       ,command=Cheesecake)
Cheesecakecake.grid(row=2,column=0,sticky=W)

Cookiescake=Checkbutton(DessertsFrame,text='Cookies',font=('arial',18,'bold'),onvalue=1,offvalue=0,variable=var22
                        ,command=Cookies)
Cookiescake.grid(row=3,column=0,sticky=W)

Puddingscake=Checkbutton(DessertsFrame,text='Puddings',font=('arial',18,'bold'),onvalue=1,offvalue=0,variable=var23
                       ,command=Puddings)
Puddingscake.grid(row=4,column=0,sticky=W)

Donutcake=Checkbutton(DessertsFrame,text='Donut',font=('arial',18,'bold'),onvalue=1,offvalue=0,variable=var24
                        ,command=Donut)
Donutcake.grid(row=5,column=0,sticky=W)

Muffincake=Checkbutton(DessertsFrame,text='Muffin',font=('arial',18,'bold'),onvalue=1,offvalue=0,variable=var25
                          ,command=Muffin)
Muffincake.grid(row=6,column=0,sticky=W)

Sundaecake=Checkbutton(DessertsFrame,text='Sundae',font=('arial',18,'bold'),onvalue=1,offvalue=0,variable=var26
                          ,command=Sundae)
Sundaecake.grid(row=7,column=0,sticky=W)

blackforestcake=Checkbutton(DessertsFrame,text='Ice Cream',font=('arial',18,'bold'),onvalue=1,offvalue=0,variable=var27
                            ,command=blackforest)
blackforestcake.grid(row=8,column=0,sticky=W)

#entry fields for Desserts

textCake = Entry(DessertsFrame, font=('arial', 18, 'bold'), bd=7, width=6, state=DISABLED, textvariable=e_Cake)
textCake.grid(row=0, column=1)

textBrownie = Entry(DessertsFrame, font=('arial', 18, 'bold'), bd=7, width=6, state=DISABLED, textvariable=e_Brownie)
textBrownie.grid(row=1, column=1)

textCheesecake = Entry(DessertsFrame, font=('arial', 18, 'bold'), bd=7, width=6, state=DISABLED, textvariable=e_Cheesecake)
textCheesecake.grid(row=2, column=1)

textCookies = Entry(DessertsFrame, font=('arial', 18, 'bold'), bd=7, width=6, state=DISABLED, textvariable=e_Cookies)
textCookies.grid(row=3, column=1)

textPuddings = Entry(DessertsFrame, font=('arial', 18, 'bold'), bd=7, width=6, state=DISABLED, textvariable=e_Puddings)
textPuddings.grid(row=4, column=1)

textDonut = Entry(DessertsFrame, font=('arial', 18, 'bold'), bd=7, width=6, state=DISABLED, textvariable=e_Donut)
textDonut.grid(row=5, column=1)

textMuffin = Entry(DessertsFrame, font=('arial', 18, 'bold'), bd=7, width=6, state=DISABLED, textvariable=e_Muffin)
textMuffin.grid(row=6, column=1)

textSundae = Entry(DessertsFrame, font=('arial', 18, 'bold'), bd=7, width=6, state=DISABLED, textvariable=e_Sundae)
textSundae.grid(row=7, column=1)

textblackforest = Entry(DessertsFrame, font=('arial', 18, 'bold'), bd=7, width=6, state=DISABLED,textvariable=e_blackforest)
textblackforest.grid(row=8, column=1)

#costlabels & entry fields

labelCostofDrinks=Label(costFrame,text='Cost of Drinks',font=('arial',16,'bold'),bg='firebrick4',fg='#F8F3A6')
labelCostofDrinks.grid(row=0,column=0)

textCostofDrinks=Entry(costFrame,font=('arial',16,'bold'),bd=6,width=14,state='readonly',textvariable=costofDrinksvar)
textCostofDrinks.grid(row=0,column=1,padx=41)

labelCostofSnacks=Label(costFrame,text='Cost of Snacks',font=('arial',16,'bold'),bg='firebrick4',fg='#F8F3A6')
labelCostofSnacks.grid(row=1,column=0)

textCostofSnacks=Entry(costFrame,font=('arial',16,'bold'),bd=6,width=14,state='readonly',textvariable=costofSnacksvar)
textCostofSnacks.grid(row=1,column=1,padx=41)

labelCostofDesserts=Label(costFrame,text='Cost of Desserts',font=('arial',16,'bold'),bg='firebrick4',fg='#F8F3A6')
labelCostofDesserts.grid(row=2,column=0)

textCostofDesserts=Entry(costFrame,font=('arial',16,'bold'),bd=6,width=14,state='readonly',textvariable=costofDessertsvar)
textCostofDesserts.grid(row=2,column=1,padx=41)

labelSubTotal=Label(costFrame,text='Sub Total',font=('arial',16,'bold'),bg='firebrick4',fg='#F8F3A6')
labelSubTotal.grid(row=0,column=2)

textSubTotal=Entry(costFrame,font=('arial',16,'bold'),bd=6,width=14,state='readonly',textvariable=subtotalvar)
textSubTotal.grid(row=0,column=3,padx=41)

labelServiceTax=Label(costFrame,text='Service Tax',font=('arial',16,'bold'),bg='firebrick4',fg='#F8F3A6')
labelServiceTax.grid(row=1,column=2)

textServiceTax=Entry(costFrame,font=('arial',16,'bold'),bd=6,width=14,state='readonly',textvariable=servicetaxvar)
textServiceTax.grid(row=1,column=3,padx=41)

labelTotalCost=Label(costFrame,text='Total Cost',font=('arial',16,'bold'),bg='firebrick4',fg='#F8F3A6')
labelTotalCost.grid(row=2,column=2)

textTotalCost=Entry(costFrame,font=('arial',16,'bold'),bd=6,width=14,state='readonly',textvariable=totalcostvar)
textTotalCost.grid(row=2,column=3,padx=41)

#Buttons

buttonTotal=Button(buttonFrame,text='Total',font=('arial',14,'bold'),fg='#F8F3A6',bg='Purple4',bd=3,padx=5,
                   command=totalcost)
buttonTotal.grid(row=0,column=0)

buttonReceipt=Button(buttonFrame,text='Receipt',font=('arial',14,'bold'),fg='#F8F3A6',bg='Purple4',bd=3,padx=5
                     ,command=receipt)
buttonReceipt.grid(row=0,column=1)

buttonSave=Button(buttonFrame,text='Save',font=('arial',14,'bold'),fg='#F8F3A6',bg='Purple4',bd=3,padx=5
                  ,command=save)
buttonSave.grid(row=0,column=2)

buttonReset=Button(buttonFrame,text='Reset',font=('arial',14,'bold'),fg='#F8F3A6',bg='Purple4',bd=3,padx=5,
                   command=reset)
buttonReset.grid(row=0,column=4)

#textarea for receipt

textReceipt=Text(recieptFrame,font=('arial',12,'bold'),bd=3,width=42,height=14)
textReceipt.grid(row=0,column=0)

#Calculator
operator='' #7+9
def buttonClick(numbers): #9
    global operator
    operator=operator+numbers
    calculatorField.delete(0,END)
    calculatorField.insert(END,operator)

def clear():
    global operator
    operator=''
    calculatorField.delete(0,END)

def answer():
    global operator
    result=str(eval(operator))
    calculatorField.delete(0,END)
    calculatorField.insert(0,result)
    operator=''



calculatorField=Entry(calculatorFrame,font=('arial',16,'bold'),width=32,bd=4)
calculatorField.grid(row=0,column=0,columnspan=4)

button7=Button(calculatorFrame,text='7',font=('arial',16,'bold'),fg='yellow',bg='Purple4',bd=6,width=6,
               command=lambda:buttonClick('7'))
button7.grid(row=1,column=0)

button8=Button(calculatorFrame,text='8',font=('arial',16,'bold'),fg='yellow',bg='Purple4',bd=6,width=6,
               command=lambda:buttonClick('8'))
button8.grid(row=1,column=1)

button9=Button(calculatorFrame,text='9',font=('arial',16,'bold'),fg='yellow',bg='Purple4',bd=6,width=6
               ,command=lambda:buttonClick('9'))
button9.grid(row=1,column=2)

buttonPlus=Button(calculatorFrame,text='+',font=('arial',16,'bold'),fg='yellow',bg='Purple4',bd=6,width=6
                  ,command=lambda:buttonClick('+'))
buttonPlus.grid(row=1,column=3)

button4=Button(calculatorFrame,text='4',font=('arial',16,'bold'),fg='yellow',bg='Purple4',bd=6,width=6
               ,command=lambda:buttonClick('4'))
button4.grid(row=2,column=0)

button5=Button(calculatorFrame,text='5',font=('arial',16,'bold'),fg='Purple4',bg='#F8F3A6',bd=6,width=6
               ,command=lambda:buttonClick('5'))
button5.grid(row=2,column=1)

button6=Button(calculatorFrame,text='6',font=('arial',16,'bold'),fg='Purple4',bg='#F8F3A6',bd=6,width=6
               ,command=lambda:buttonClick('6'))
button6.grid(row=2,column=2)

buttonMinus=Button(calculatorFrame,text='-',font=('arial',16,'bold'),fg='yellow',bg='Purple4',bd=6,width=6
                   ,command=lambda:buttonClick('-'))
buttonMinus.grid(row=2,column=3)

button1=Button(calculatorFrame,text='1',font=('arial',16,'bold'),fg='yellow',bg='Purple4',bd=6,width=6
               ,command=lambda:buttonClick('1'))
button1.grid(row=3,column=0)

button2=Button(calculatorFrame,text='2',font=('arial',16,'bold'),fg='Purple4',bg='#F8F3A6',bd=6,width=6
               ,command=lambda:buttonClick('2'))
button2.grid(row=3,column=1)

button3=Button(calculatorFrame,text='3',font=('arial',16,'bold'),fg='Purple4',bg='#F8F3A6',bd=6,width=6
               ,command=lambda:buttonClick('3'))
button3.grid(row=3,column=2)

buttonMult=Button(calculatorFrame,text='*',font=('arial',16,'bold'),fg='yellow',bg='Purple4',bd=6,width=6
                  ,command=lambda:buttonClick('*'))
buttonMult.grid(row=3,column=3)

buttonAns=Button(calculatorFrame,text='Ans',font=('arial',16,'bold'),fg='yellow',bg='Purple4',bd=6,width=6,
                 command=answer)
buttonAns.grid(row=4,column=0)

buttonClear=Button(calculatorFrame,text='Clear',font=('arial',16,'bold'),fg='yellow',bg='Purple4',bd=6,width=6
                   ,command=clear)
buttonClear.grid(row=4,column=1)

button0=Button(calculatorFrame,text='0',font=('arial',16,'bold'),fg='yellow',bg='Purple4',bd=6,width=6
               ,command=lambda:buttonClick('0'))
button0.grid(row=4,column=2)

buttonDiv=Button(calculatorFrame,text='/',font=('arial',16,'bold'),fg='yellow',bg='Purple4',bd=6,width=6,
                 command=lambda:buttonClick('/'))
buttonDiv.grid(row=4,column=3)

root.mainloop()
